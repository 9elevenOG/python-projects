# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style for better aesthetics
sns.set(style="whitegrid")

# %%
# Load the dataset
df = pd.read_csv("/content/automobile_dataset.csv")

# %%
df.head()
# Out:
#      price  highway-mpg  city-mpg  peak-rpm  horsepower  compression-ratio  \
# 0  13495.0           27        21    5000.0       111.0                9.0
# 1  16500.0           27        21    5000.0       111.0                9.0
# 2  16500.0           26        19    5000.0       154.0                9.0
# 3  13950.0           30        24    5500.0       102.0               10.0
# 4  17450.0           22        18    5500.0       115.0                8.0
#
#    stroke  bore fuel-system  engine-size  ...  wheel-base engine-location  \
# 0    2.68  3.47        mpfi          130  ...        88.6           front
# 1    2.68  3.47        mpfi          130  ...        88.6           front
# 2    3.47  2.68        mpfi          152  ...        94.5           front
# 3    3.40  3.19        mpfi          109  ...        99.8           front
# 4    3.40  3.19        mpfi          136  ...        99.4           front
#
#    drive-wheels   body-style  num-of-doors  aspiration  fuel-type  \
# ...

# %%
df.describe()
# Out:
#               price  highway-mpg    city-mpg     peak-rpm  horsepower  \
# count    201.000000   205.000000  205.000000   203.000000  203.000000
# mean   13207.129353    30.751220   25.219512  5125.369458  104.256158
# std     7947.066342     6.886443    6.542142   479.334560   39.714369
# min     5118.000000    16.000000   13.000000  4150.000000   48.000000
# 25%     7775.000000    25.000000   19.000000  4800.000000   70.000000
# 50%    10295.000000    30.000000   24.000000  5200.000000   95.000000
# 75%    16500.000000    34.000000   30.000000  5500.000000  116.000000
# max    45400.000000    54.000000   49.000000  6600.000000  288.000000
#
#        compression-ratio      stroke        bore  engine-size  \
# count         205.000000  201.000000  201.000000   205.000000
# mean           10.142537    3.255423    3.329751   126.907317
# std             3.972040    0.316717    0.273539    41.642693
# min             7.000000    2.070000    2.540000    61.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              201 non-null    float64
#  1   highway-mpg        205 non-null    int64
#  2   city-mpg           205 non-null    int64
#  3   peak-rpm           203 non-null    float64
#  4   horsepower         203 non-null    float64
#  5   compression-ratio  205 non-null    float64
#  6   stroke             201 non-null    float64
#  7   bore               201 non-null    float64
#  8   fuel-system        205 non-null    object
#  9   engine-size        205 non-null    int64
#  10  num-of-cylinders   205 non-null    int64
#  11  engine-type        205 non-null    object
#  12  curb-weight        205 non-null    int64
#  13  height             205 non-null    float64
#  14  width              205 non-null    float64
#  15  length             205 non-null    float64
# ...

# %%
print(df.isnull().sum())
# Out:
# price                 4
# highway-mpg           0
# city-mpg              0
# peak-rpm              2
# horsepower            2
# compression-ratio     0
# stroke                4
# bore                  4
# fuel-system           0
# engine-size           0
# num-of-cylinders      0
# engine-type           0
# curb-weight           0
# height                0
# width                 0
# length                0
# wheel-base            0
# engine-location       0
# drive-wheels          0
# body-style            0
# num-of-doors          2
# aspiration            0
# fuel-type             0
# make                  0
# normalized-losses    41
# symboling             0
# dtype: int64

# %%
for col in ['normalized-losses', 'price', 'horsepower']:
    if col in df.columns and df[col].isnull().sum() > 0:
        df[col].fillna(df[col].median(), inplace=True)
# Out:
# <ipython-input-9-2425f79445a4>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %%
for col in ['stroke', 'bore', 'num-of-doors', 'peak-rpm']:
    if col in df.columns and df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# <ipython-input-10-a8ceffb77f16>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
print(df.isnull().sum())
# Out:
# price                0
# highway-mpg          0
# city-mpg             0
# peak-rpm             0
# horsepower           0
# compression-ratio    0
# stroke               0
# bore                 0
# fuel-system          0
# engine-size          0
# num-of-cylinders     0
# engine-type          0
# curb-weight          0
# height               0
# width                0
# length               0
# wheel-base           0
# engine-location      0
# drive-wheels         0
# body-style           0
# num-of-doors         0
# aspiration           0
# fuel-type            0
# make                 0
# normalized-losses    0
# symboling            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Univariate Analysis
#1. Numerical Columns
# Plot histograms for numerical columns
numerical_cols = ['normalized-losses', 'engine-size', 'horsepower', 'price']
for col in numerical_cols:
    if col in df.columns:
        plt.figure(figsize=(8, 5))
        sns.histplot(df[col], kde=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.show()

# %%
#Categorical Columns
# Plot bar plots for categorical columns
categorical_cols = ['make', 'fuel-type', 'body-style', 'num-of-cylinders']
for col in categorical_cols:
    if col in df.columns:
        plt.figure(figsize=(10, 5))
        sns.countplot(data=df, x=col)
        plt.title(f'Count of {col}')
        plt.xticks(rotation=90)
        plt.show()

# %%
#Bivariate Analysis
#Correlation Matrix (for numerical variables)
# Compute correlation matrix
numerical_cols = ['symboling', 'normalized-losses', 'engine-size', 'horsepower', 'price']
corr_matrix = df[numerical_cols].corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
#Symboling vs. Categorical Variables
# Boxplot of symboling by make
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='make', y='symboling')
plt.title('Symboling by Car Make')
plt.xticks(rotation=45)
plt.show()

# Boxplot of symboling by fuel-type
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='fuel-type', y='symboling')
plt.title('Symboling by Fuel Type')
plt.show()

# %%
#Normalized Losses vs. Numerical Variables
# Scatter plot of normalized-losses vs. horsepower
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='horsepower', y='normalized-losses', hue='fuel-type')
plt.title('Normalized Losses vs. Horsepower')
plt.show()

# %%
# Identify outliers using IQR for numerical columns
for col in ['normalized-losses', 'horsepower', 'price']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        outliers = df[(df[col] < Q1 - 1.5 * IQR) | (df[col] > Q3 + 1.5 * IQR)][col]
        print(f"Outliers in {col}: {len(outliers)}")
# Out:
# Outliers in normalized-losses: 8
# Outliers in horsepower: 6
# Outliers in price: 14

# %%
#Visualize Outliers
# Boxplots for columns with outliers
for col in ['normalized-losses', 'horsepower', 'price']:
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df, y=col)
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df.to_csv("/content/automobile_dataset.csv", index=False)
print("Cleaned dataset saved as '/content/automobile_dataset.csv'")
# Out:
# Cleaned dataset saved as '/content/automobile_dataset.csv'
